# %% [markdown]
# # Generación de Datos Sinteticos

# %% [markdown]
# # Instalación y preparación del entorno de trabajo Retailmax
#
# ## Objetivo
#
# Instalar las bibliotecas necesarias para el desarrollo del proyecto y garantizar que todas las dependencias estén disponibles antes de iniciar el procesamiento de datos.
#
# ## Librerías instaladas
#
# | Librería | Propósito |
# |----------|-----------|
# | **Faker** | Generación de datos sintéticos para pruebas y simulaciones. |
# | **pandas** | Manipulación y análisis de datos mediante DataFrames. |
# | **numpy** | Operaciones matemáticas y manejo eficiente de arreglos numéricos. |
# | **scipy** | Funciones científicas, estadísticas y matemáticas avanzadas. |
# | **PyYAML** | Lectura y escritura de archivos de configuración en formato YAML. |
# | **pyarrow** | Lectura y escritura de formatos columnar como Parquet y optimización del intercambio de datos con Apache Arrow. |
#
# ## Reinicio del entorno
#
# Al finalizar la instalación se ejecuta:
#
# `dbutils.library.restartPython()`
#
# Este comando reinicia el intérprete de Python para que las nuevas librerías queden cargadas correctamente y puedan utilizarse durante el resto del notebook.
#
# ## Resultado esperado
#
# - Todas las dependencias quedan instaladas correctamente.
# - El entorno se reinicia automáticamente.
# - El notebook queda preparado para importar las librerías en las siguientes celdas.

# %%
# Instalación de los paquetes requeridos

# !pip install Faker
# !pip install pandas
# !pip install numpy
# !pip install scipy
# !pip install PyYAML
# !pip install pyarrow

# Reinicio del entorno de Python para aplicar los cambios
dbutils.library.restartPython()

# %% [markdown]
# # 📚 Importación de librerías y módulos
#
# ## Objetivo
#
# Importar todas las librerías que serán utilizadas durante el desarrollo del notebook para la generación de datos sintéticos, manipulación de información, análisis estadístico, almacenamiento de archivos y manejo de configuraciones.
#
# ## Librerías utilizadas
#
# | Librería | Descripción | Uso en el proyecto |
# |----------|-------------|--------------------|
# | **faker** | Genera datos sintéticos realistas como nombres, direcciones, correos y teléfonos. | Creación de datasets de prueba. |
# | **pandas (pd)** | Biblioteca para análisis y manipulación de datos mediante DataFrames. | Transformación, limpieza y análisis de datos. |
# | **numpy (np)** | Proporciona estructuras de datos numéricas y operaciones matemáticas de alto rendimiento. | Generación de valores aleatorios y cálculos numéricos. |
# | **scipy.stats** | Módulo estadístico de SciPy para trabajar con distribuciones y simulaciones probabilísticas. | Generación de datos con distribuciones estadísticas y análisis. |
# | **yaml** | Permite leer y escribir archivos de configuración en formato YAML. | Configuración externa del proyecto. |
# | **pyarrow (pa)** | Implementación de Apache Arrow para el intercambio eficiente de datos entre sistemas. | Optimización del procesamiento de datos. |
# | **pyarrow.parquet (pq)** | Herramientas para leer y escribir archivos en formato Parquet. | Persistencia de datos en formato columnar. |
# | **os** | Proporciona funciones para interactuar con el sistema operativo. | Gestión de archivos y directorios. |
# | **json** | Permite serializar y deserializar información en formato JSON. | Lectura y escritura de archivos JSON. |
# | **datetime** | Manejo de fechas y horas. | Generación de marcas de tiempo y control temporal de los datos. |
# | **time** | Funciones relacionadas con el tiempo y pausas de ejecución. | Medición de tiempos de procesamiento y esperas. |
# | **random** | Generación de valores aleatorios mediante la librería estándar de Python. | Simulación de escenarios y selección aleatoria de datos. |
#
# ## Resultado esperado
#
# Al finalizar esta celda:
#
# - Todas las dependencias quedan disponibles en memoria.
# - El notebook está preparado para generar datos sintéticos.
# - Se habilitan las herramientas necesarias para la manipulación, análisis y almacenamiento de datos.
# - Las siguientes etapas podrán trabajar con DataFrames, distribuciones estadísticas, archivos Parquet y configuraciones externas sin necesidad de volver a importar estas librerías.

# %%
# Importación de librerías
import faker
import pandas as pd
import numpy as np
import scipy.stats as stats
import yaml
import pyarrow as pa
import pyarrow.parquet as pq
import os
import json
import datetime
import time
import random

# %%
from faker import Faker 
from faker.providers import bank,company,internet, person
fake=Faker("es_CO")
fake.add_provider(bank)

for _ in range(10):
  print(fake.name())
  #print(faker.address())
  fake.add_provider(bank)
  fake.add_provider(company)
  fake.add_provider(internet)
  fake.add_provider(person)
  print(fake.name())
  print(fake.address())
  print(fake.credit_card_number())
  print(fake.credit_card_provider())
  print(fake.credit_card_expire())
  print(fake.credit_card_security_code())
  print(fake.company())
  print(fake.company_email

# %%
  for _ in range(1_000_000):

    producto = random.choices(
        productos,
        weights=pesos,
        k=1
    )[0]

    registro = {
        ...
    }

    registros.append(registro)

# %%
demanda = [item["demanda"] for item in productos]

producto = random.choices(
    productos,
    weights=demanda,
    k=1
)[0]

producto = random.choices(
    articulos,
    weights=[x["apariciones"] for x in articulos],
    k=1
)[0]
